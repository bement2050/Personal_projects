# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

# %%
list_of_titles=[]

# %%
for i in list(range(23,190)):
    r=requests.get('https://www.qwiklabs.com/quests/{k}'.format(k=i))
    title=re.findall('<title>(.*?)</title>',r.text)[0].split('|')[0]
    list_of_titles.append(title)

# %%
'https://www.qwiklabs.com/quests/{k}'.format(k=j)
# Out:
# 'https://www.qwiklabs.com/quests/5'

# %%
list_of_titles
# Out:
# ['Google Cloud Essentials ',
#  'Cloud Architecture ',
#  'Data Engineering ',
#  'Deploying Applications ',
#  'Windows on Google Cloud ',
#  'Scientific Data Processing ',
#  'Kubernetes in Google Cloud ',
#  'Qwiklabs',
#  'Networking in Google Cloud  ',
#  'Machine Learning APIs ',
#  'Baseline: Infrastructure ',
#  'Baseline: Data, ML, AI ',
#  'Google Cloud&#39;s Operations Suite ',
#  'Google Cloud Solutions I: Scaling Your Infrastructure ',
#  'Baseline: Deploy &amp; Develop ',
#  'Google Cloud Solutions II: Data and Machine Learning ',
#  'Websites and Web Applications ',
#  'Security &amp; Identity Fundamentals ',
#  'Application Development - Python ',
#  'Application Development - Java ',
#  'Data Science on Google Cloud ',
#  'Managing Cloud Infrastructure with Terraform ',
#  'Kubernetes Solutions ',
#  'Network Performance and Optimization ',
#  'Qwiklabs',
#  'Developing Data and Machine Learning Apps with C# ',
#  'IoT in the Google Cloud ',
#  'Data Science on Google Cloud: Machine Learning ',
#  'Workspace: Integrations ',
#  'Cloud SQL ',
#  'Qwiklabs',
#  'Exploring APIs ',
#  'Qwiklabs',
#  'Qwiklabs',
#  'Qwiklabs',
#  'NCAA® March Madness®: Bracketology with Google Cloud ',
#  'Qwiklabs',
#  'Qwiklabs',
#  'OK Google: Build Interactive Apps with Google Assistant ',
#  'Public Cloud Security by Palo Alto Networks ',
#  'Qwiklabs',
#  'Qwiklabs',
#  'Workspace Essentials ',
#  'Cloud Engineering ',
#  'Cloud Development ',
#  'BigQuery for Data Warehousing ',
#  'BigQuery Basics for Data Analysts ',
#  'BigQuery for Marketing Analysts ',
#  'BigQuery for Machine Learning ']

# %%
courses_link=pd.DataFrame(list_of_titles)

# %%
courses_link['link']=['https://www.qwiklabs.com/quests/{k}'.format(k=i) for i in list(range(23,72))]

# %%
courses_link
# Out:
#                                                     0  \
# 0                            Google Cloud Essentials
# 1                                 Cloud Architecture
# 2                                   Data Engineering
# 3                             Deploying Applications
# 4                            Windows on Google Cloud
# 5                         Scientific Data Processing
# 6                         Kubernetes in Google Cloud
# 7                                            Qwiklabs
# 8                        Networking in Google Cloud
# 9                              Machine Learning APIs
# 10                          Baseline: Infrastructure
# 11                            Baseline: Data, ML, AI
# 12               Google Cloud&#39;s Operations Suite
# 13  Google Cloud Solutions I: Scaling Your Infrast...
# 14                    Baseline: Deploy &amp; Develop
# 15  Google Cloud Solutions II: Data and Machine Le...
# 16                     Websites and Web Applications
# 17              Security &amp; Identity Fundamentals
# 18                  Application Development - Python
# 19                    Application Development - Java
# 20                      Data Science on Google Cloud
# 21      Managing Cloud Infrastructure with Terraform
# 22                              Kubernetes Solutions
# 23              Network Performance and Optimization
# 24                                           Qwiklabs
# 25  Developing Data and Machine Learning Apps with...
# 26                           IoT in the Google Cloud
# 27    Data Science on Google Cloud: Machine Learning
# 28                           Workspace: Integrations
# 29                                         Cloud SQL
# 30                                           Qwiklabs
# 31                                    Exploring APIs
# 32                                           Qwiklabs
# 33                                           Qwiklabs
# 34                                           Qwiklabs
# 35  NCAA® March Madness®: Bracketology with Google...
# 36                                           Qwiklabs
# 37                                           Qwiklabs
# 38  OK Google: Build Interactive Apps with Google ...
# 39       Public Cloud Security by Palo Alto Networks
# 40                                           Qwiklabs
# 41                                           Qwiklabs
# 42                              Workspace Essentials
# 43                                 Cloud Engineering
# 44                                 Cloud Development
# 45                     BigQuery for Data Warehousing
# 46                 BigQuery Basics for Data Analysts
# 47                   BigQuery for Marketing Analysts
# 48                     BigQuery for Machine Learning
#
#                                   link
# 0   https://www.qwiklabs.com/quests/23
# 1   https://www.qwiklabs.com/quests/24
# 2   https://www.qwiklabs.com/quests/25
# 3   https://www.qwiklabs.com/quests/26
# 4   https://www.qwiklabs.com/quests/27
# 5   https://www.qwiklabs.com/quests/28
# 6   https://www.qwiklabs.com/quests/29
# 7   https://www.qwiklabs.com/quests/30
# 8   https://www.qwiklabs.com/quests/31
# 9   https://www.qwiklabs.com/quests/32
# 10  https://www.qwiklabs.com/quests/33
# 11  https://www.qwiklabs.com/quests/34
# 12  https://www.qwiklabs.com/quests/35
# 13  https://www.qwiklabs.com/quests/36
# 14  https://www.qwiklabs.com/quests/37
# 15  https://www.qwiklabs.com/quests/38
# 16  https://www.qwiklabs.com/quests/39
# 17  https://www.qwiklabs.com/quests/40
# 18  https://www.qwiklabs.com/quests/41
# 19  https://www.qwiklabs.com/quests/42
# 20  https://www.qwiklabs.com/quests/43
# 21  https://www.qwiklabs.com/quests/44
# 22  https://www.qwiklabs.com/quests/45
# 23  https://www.qwiklabs.com/quests/46
# 24  https://www.qwiklabs.com/quests/47
# 25  https://www.qwiklabs.com/quests/48
# 26  https://www.qwiklabs.com/quests/49
# 27  https://www.qwiklabs.com/quests/50
# 28  https://www.qwiklabs.com/quests/51
# 29  https://www.qwiklabs.com/quests/52
# 30  https://www.qwiklabs.com/quests/53
# 31  https://www.qwiklabs.com/quests/54
# 32  https://www.qwiklabs.com/quests/55
# 33  https://www.qwiklabs.com/quests/56
# 34  https://www.qwiklabs.com/quests/57
# 35  https://www.qwiklabs.com/quests/58
# 36  https://www.qwiklabs.com/quests/59
# 37  https://www.qwiklabs.com/quests/60
# 38  https://www.qwiklabs.com/quests/61
# 39  https://www.qwiklabs.com/quests/62
# 40  https://www.qwiklabs.com/quests/63
# 41  https://www.qwiklabs.com/quests/64
# 42  https://www.qwiklabs.com/quests/65
# 43  https://www.qwiklabs.com/quests/66
# 44  https://www.qwiklabs.com/quests/67
# 45  https://www.qwiklabs.com/quests/68
# 46  https://www.qwiklabs.com/quests/69
# 47  https://www.qwiklabs.com/quests/70
# 48  https://www.qwiklabs.com/quests/71
